# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/ForecastStocks')
os.getcwd()
# Out:
# '/content/drive/MyDrive/ForecastStocks'

# %%
# Importing libraries
from Scripts import *

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
output,forecasted=forecast('TCS.NS')
# Out:
# File history_fibonacciTCS.NS.csv has been saved

# %%
forecasted
# Out:
# Date
# 2022-03-16    3594.643066
# 2022-03-17    3645.355713
# 2022-03-18    3645.508301
# 2022-03-21    3646.763184
# 2022-03-22    3648.846680
# 2022-03-23    3651.543213
# 2022-03-24    3654.687256
# 2022-03-25    3658.153076
# 2022-03-28    3661.847900
# 2022-03-29    3665.703125
# 2022-03-30    3669.667969
# 2022-03-31    3673.706299
# 2022-04-01    3677.792725
# 2022-04-04    3681.907471
# 2022-04-05    3686.034912
# 2022-04-06    3690.162598
# Name: Predictions, dtype: float32
